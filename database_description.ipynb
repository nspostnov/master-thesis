# %% [markdown]
# Этот скрипт предназначен для анализа составленной базы данных: интересуют характеристики активности рынков: как в целом, так и в срезах по тикерам.

# %%
from psycopg2 import connect as cnct
from datetime import datetime

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # 0. Подготовка глобальных переменных

# %% [markdown]
# Здесь записывается параметры подключения к базе данных, ее имя, а также рассчитываются основные глобальные параметры:
# 1. Названия всех таблиц в базе данных
# 2. Все тикеры инструментов, присутствующие в данных

# %%
DB_NAME = 'orderlogs'
DB_SETTINGS = {
    'dbname': DB_NAME,
    'user': 'postgres',
    'password': '',
    'host': 'localhost',
    'port': 5432
}

with cnct(**DB_SETTINGS) as conn:
    cur = conn.cursor()
    cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public'")
    TABLE_NAMES = cur.fetchall()
    TABLE_NAMES = sorted(list(map(lambda x: x[0], TABLE_NAMES)))

# %%
SECCODES = []
for table_name in TABLE_NAMES:
    with cnct(**DB_SETTINGS) as conn:
        cur = conn.cursor()
        cur.execute(f'SELECT DISTINCT "SECCODE" FROM "{table_name}"')
        SECCODES.extend(list(map(lambda x: x[0], cur.fetchall())))
SECCODES = sorted(list(np.unique(np.array(SECCODES))))

# %%
def date_convertion(date):
    '''This function converts date in int format like 20190101 to POSIX
    
    :date: date in int format
    '''
    year = int(str(date)[:4])
    month = int(str(date)[4:6])
    day = int(str(date)[6:])
    
    return datetime(year, month, day, )

# %% [markdown]
# # 1. Оценка размера ежедневной активности

# %% [markdown]
# ## 1.1. Общая активность

# %% [markdown]
# Произведем расчет количества заявок по рынку в целом, чтобы было представление об активности на рынках. Здесь помимо фундаментально торгующих инвесторов так же присутствует информация о HFT торгах: активность алгоритмической торговли.

# %%
activity_value = []
for table_name in TABLE_NAMES:
    print(table_name)
    with cnct(**DB_SETTINGS) as conn:
        cur = conn.cursor()
        cur.execute(f'SELECT COUNT(*) from "{table_name}"')
        orders_count = cur.fetchone()[0]  # the return is tuple, we need the first value
        activity_value.append((table_name, orders_count))
activity_value = pd.DataFrame(activity_value, columns=['Date', 'Number of Orders'])
activity_value['Date'] = list(map(date_convertion, activity_value['Date']))

# %%
activity_value.to_csv('./data_results/description/tables_activity/activity_market_all.csv', index=False)

# %%
plt.figure()
plt.plot(activity_value['Date'],
         activity_value['Number of Orders'])
plt.xticks(rotation=15)
plt.title('The Activity of Stock Market, num of orders')

plt.savefig('./data_results/description/figures_activity/activity_stock_market_all.pdf', )

# %% [markdown]
# ## 1.2. Активность в разрезе по тикерам

# %% [markdown]
# Аналогичный расчет подготовим по всем финансовым инструментам, по которым была активность по составленной БД (июнь 2019).

# %%
def activity_calculation(seccode):
    '''This function calculates the market activity by ticker (by fin. instrument).
    
    :seccode: str parameter (for example, 'SBER')
    :return: pd.DataFrame object with columns Date, Seccode, Number of Orders; this dataframe is saved to the
        .csv file to the further usage
    '''
    activity_value_tickers = []
    for table_name in TABLE_NAMES:
        print(table_name, seccode)
        with cnct(**DB_SETTINGS) as conn:
            cur = conn.cursor()
            try:
                cur.execute(f'''SELECT COUNT(*) from "{table_name}" WHERE "SECCODE" = '{seccode}';''')
                count = cur.fetchone()[0]
                activity_value_tickers.append((table_name, seccode, count))
            except:
                pass
    activity_value_tickers = pd.DataFrame(activity_value_tickers, columns=['Date', 'Seccode', 'Number of Orders'])
    activity_value_tickers['Date'] = list(map(date_convertion, activity_value_tickers['Date']))
    
    activity_value_tickers.to_csv(f'./data_results/description/tables_activity/activity_market_{seccode}.csv', index=False)

    return activity_value_tickers

# %%
def activity_plot(activity_value_ticker, seccode):
    '''This function plots the result of activity_calculation function
    
    :activity_value_ticker: pd.DataFrame object that is return of activity_calculation function
    :seccode: str name of fin. instrument (for example, 'SBER')
    :return: None, the plot is saved into .pdf file 
    '''
    plt.figure()
    plt.plot(activity_value_ticker['Date'],
             activity_value_ticker['Number of Orders'])
    plt.xticks(rotation=15)
    plt.title(f'The Activity of {seccode}, num of orders')

    plt.savefig(f'./data_results/description/figures_activity/activity_stock_market_{seccode}.pdf')
    plt.close

# %%
for seccode in SECCODES:
    activity_data = activity_calculation(seccode)
    activity_plot(activity_data, seccode)

# %% [markdown]
# # 2. Анализ объема торгов

# %% [markdown]
# Здесь необходима оценка глубины рынков как общая, так и в разрезе по тикерам. Оценка глубины показывает денежное выражение в заключенных сделках. По полученной информации можно отфильтровать большое число инструментов для учета только наиболее ликвидных инструментов как тех, которые вносят больший вклад в качество рынка.

# %% [markdown]
# ## 2.1. Общий объем торгов

# %%
def sum_volume_market_day(table_name):
    '''This function calculates the overall traded volume in 
    money that occurs during the day that is specified in the table
    
    :table_name: the name of table in the database ('20190603' for example)
    :return: float number that is overall traded volume
    '''
    with cnct(**DB_SETTINGS) as conn:
        cur = conn.cursor()
        query = f'SELECT sum("VOLUME" * "TRADEPRICE") FROM "{table_name}" WHERE ' +\
            f'"{table_name}"."ACTION"=2 ' +\
            f'AND "{table_name}"."BUYSELL"=\'B\';'

        cur.execute(query)

        result = cur.fetchall()[0][0]  # return is the list consists of tuple with 1 value
    return result


def sum_volume_market_month():
    '''This function calculates the same as the sum_volume_market_day function but for all the days that
    exist in the data base. 
    
    :return: the pd.DataFrame object with columns Date, TRADEDVOLUME
    '''
    df_return = []
    for table_name in TABLE_NAMES:
        print(table_name)
        try:
            volume_day = sum_volume_market_day(table_name)
            if np.float(volume_day) == np.nan:
                volume_day = 0
        except:
            volume_day = 0
    
        df_return.append((date_convertion(table_name), volume_day))
    
    return pd.DataFrame(df_return, columns=['Date', 'TRADEDVOLUME'])


def tradedvolume_plot_market(df):
    '''This function plots the result of sum_volume_market_month
    
    :df: pd.DataFrame object that is return of sum_volume_market_month function
    :return: None, the plot is saved into .pdf file 
    '''
    plt.figure()
    plt.plot(df['Date'],
             df['TRADEDVOLUME'])
    plt.xticks(rotation=15)
    plt.title(f'The Traded Volume of Market, rub')

    plt.savefig(f'./data_results/description/figures_tradedvolume/tradedvolume_market.pdf')
    plt.close()

# %%
df = sum_volume_market_month()
df.to_csv(f'./data_results/description/tables_tradedvolume/tradedvolume_market.csv', index=False)
tradedvolume_plot_market(df)
# Out:
# 20190603
# 20190604
# 20190605
# 20190606
# 20190607
# 20190610
# 20190611
# 20190613
# 20190614
# 20190617
# 20190618
# 20190619
# 20190620
# 20190621
# 20190624
# 20190625
# 20190626
# 20190627
# 20190628
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 2.2. Объем торгов в разрезе по тикерам

# %%
def sum_volume_ticker_day(ticker, table_name):
    '''This function calculates the traded volume in money by ticker at the specified date
    
    :ticker: str name of fin. instrument (for example, 'SBER')
    :table_name: the name of postgresql table (for example, '20190603')
    :return: the float number of sum of daily traded volume (in money, rub)
    '''
    with cnct(**DB_SETTINGS) as conn:
        cur = conn.cursor()
        query = f'SELECT sum("VOLUME" * "TRADEPRICE") FROM "{table_name}" WHERE ' +\
            f'"{table_name}"."ACTION"=2 ' +\
            f'AND "{table_name}"."SECCODE"=\'{ticker}\' ' +\
            f'AND "{table_name}"."BUYSELL"=\'B\';'

        cur.execute(query)

        result = cur.fetchall()[0][0]  # return is the list consists of tuple with 1 value
    
    return result


def sum_volume_ticker_month(ticker):
    '''This function calculates the same as the sum_volume_ticker_day function but for all the days that
    exist in the data base. 
    
    :ticker: str name of fin. instrument (for example, 'SBER')
    :return: the pd.DataFrame object with columns Date, SECCODE, TRADEDVOLUME
    '''
    df_return = []
    for table_name in TABLE_NAMES:
        print(ticker, table_name)
        try:
            volume_day = sum_volume_ticker_day(ticker, table_name)
            if np.float(volume_day) == np.nan:
                volume_day = 0
        except:
            volume_day = 0
    
        df_return.append((date_convertion(table_name), ticker, volume_day))
    
    return pd.DataFrame(df_return, columns=['Date', 'SECCODE', 'TRADEDVOLUME'])


def tradedvolume_plot(df, seccode):
    '''This function plots the result of sum_volume_ticker_month
    
    :df: pd.DataFrame object that is return of sum_volume_ticker_month function
    :seccode: str name of fin. instrument (for example, 'SBER')
    :return: None, the plot is saved into .pdf file 
    '''
    plt.figure()
    plt.plot(df['Date'],
             df['TRADEDVOLUME'])
    plt.xticks(rotation=15)
    plt.title(f'The Traded Volume of {seccode}, rub')

    plt.savefig(f'./data_results/description/figures_tradedvolume/tradedvolume_{seccode}.pdf')
    plt.close()

# %%
for seccode in SECCODES:
    df = sum_volume_ticker_month(seccode)
    df.to_csv(f'./data_results/description/tables_tradedvolume/tradedvolume_{seccode}.csv', index=False)
    tradedvolume_plot(df, seccode)

# %% [markdown]
# # 3. Отбор инструментов

# %%
path = os.path.join(os.path.abspath(''), 'data_results/description/tables_tradedvolume')
filenames = os.listdir(path)
filenames = sorted(list(filter(lambda x: x[-3:]=='csv', filenames)))

df = pd.DataFrame(columns=['Date', 'SECCODE', 'TRADEDVOLUME'])
for file in filenames:
    if file != 'tradedvolume_market.csv':
        df_readed = pd.read_csv(os.path.join(path, file))
        df = pd.concat((df, df_readed))
    else:
        pass
df = df.reset_index(drop=True).sort_values(by=['SECCODE', 'Date'])

df_overall_sorted = df.groupby('SECCODE').agg({
    'Date': lambda x: datetime.strptime(x.iloc[-1][:-3], '%Y-%m'),
    'TRADEDVOLUME': np.sum
}).drop('Date', axis=1).sort_values(by='TRADEDVOLUME', ascending=False).reset_index()
df_overall_sorted['% of total'] = df_overall_sorted['TRADEDVOLUME'] / np.sum(df_overall_sorted.TRADEDVOLUME) * 100

df_overall_sorted['% of total cumulative'] = np.cumsum(df_overall_sorted['% of total'])
df_overall_sorted.to_csv('./data_results/selection/volume_partition.csv')

# %% [markdown]
# Оставляем топ 58 тикеров, которые за все время торгов составляют хотя бы 0.5% от всего рынка. Кумулятивно такие тикеры вместе показывают 99.1% рынка.

# %%
seccode_for_spec = sorted(df_overall_sorted['SECCODE'][0:58])

path_to_spec = os.path.join(os.path.abspath(''), 'data_from_moex_web')

spec = pd.read_excel(os.path.join(path_to_spec, 'list-archive-01062019.xlsx'), header=1)
filter_ = np.array(list(map(lambda x: x in seccode_for_spec, spec['Торговый код'])))
spec = spec.loc[filter_].reset_index(drop=True)
spec
# Out:
#            Листинг Дата включения в список  \
# 0   Первый уровень              2014-06-09
# 1   Первый уровень              2014-06-09
# 2   Первый уровень              2014-06-09
# 3   Первый уровень              2014-06-09
# 4   Первый уровень              2014-06-09
# 5   Первый уровень              2014-06-09
# 6   Первый уровень              2014-06-09
# 7   Первый уровень              2014-06-09
# 8   Первый уровень              2014-06-09
# 9   Первый уровень              2014-06-09
# 10  Первый уровень              2014-06-09
# 11  Первый уровень              2014-06-09
# 12  Первый уровень              2014-06-09
# 13  Первый уровень              2014-06-09
# 14  Первый уровень              2014-06-09
# 15  Первый уровень              2014-06-09
# 16  Первый уровень              2014-06-09
# 17  Первый уровень              2014-06-09
# 18  Первый уровень              2014-06-09
# 19  Первый уровень              2014-06-09
# 20  Первый уровень              2014-06-09
# 21  Первый уровень              2014-06-09
# 22  Первый уровень              2014-06-09
# 23  Первый уровень              2014-06-09
# 24  Первый уровень              2014-06-09
# 25  Первый уровень              2014-06-09
# 26  Первый уровень              2014-06-09
# 27  Первый уровень              2014-06-09
# 28  Первый уровень              2014-06-09
# 29  Первый уровень              2014-06-09
# 30  Первый уровень              2014-06-09
# 31  Первый уровень              2014-06-09
# 32  Первый уровень              2014-06-09
# 33  Первый уровень              2014-06-11
# 34  Первый уровень              2014-09-01
# 35  Первый уровень              2015-01-19
# 36  Первый уровень              2015-03-23
# 37  Первый уровень              2015-06-22
# 38  Первый уровень              2015-08-31
# 39  Первый уровень              2016-04-13
# 40  Первый уровень              2016-08-30
# 41  Первый уровень              2017-01-24
# 42  Первый уровень              2017-02-08
# 43  Первый уровень              2018-01-29
# 44  Первый уровень              2019-01-24
# 45  Второй уровень              2014-06-09
# 46  Второй уровень              2014-06-09
# 47  Второй уровень              2014-06-09
# 48  Второй уровень              2014-06-09
# 49  Второй уровень              2014-06-09
# 50  Второй уровень              2017-01-31
# 51  Третий уровень              2014-06-09
# 52  Третий уровень              2014-06-09
# 53  Третий уровень              2014-06-09
# 54  Третий уровень              2016-12-30
# 55  Третий уровень              2017-01-31
# 56  Третий уровень              2017-07-04
# 57  Третий уровень              2019-04-16
#
#                                               Эмитент         ИНН  \
# 0   Polymetal International plc (Полиметалл Интерн...    10033331
# 1                                   АК "АЛРОСА" (ПАО)  1433000147
# 2                                      Банк ВТБ (ПАО)  7702070139
# 3                                      ПАО "Аэрофлот"  7712040126
# 4                        ПАО "ГМК "Норильский никель"  8401005730
# 5                                       ПАО "Газпром"  7736050003
# 6                           ПАО "Группа Компаний ПИК"  7713011336
# 7                                    ПАО "Группа ЛСР"  7838360491
# 8                                        ПАО "ЛУКОЙЛ"  7708004767
# 9                                       ПАО "М.видео"  7707602010
# 10                                          ПАО "МТС"  7740000076
# 11                                       ПАО "Магнит"  2309085638
# 12                                        ПАО "Мечел"  7703370008
# 13                                        ПАО "Мечел"  7703370008
# 14                                    ПАО "Мосэнерго"  7705035012
# 15                                 ПАО "НК "Роснефть"  7706107510
# 16                                      ПАО "НОВАТЭК"  6316031581
# 17                                   ПАО "Ростелеком"  7707049388
# 18                                     ПАО "РусГидро"  2460066195
# 19                                   ПАО "Северсталь"  3528000597
# 20                                        ПАО "ТГК-1"  7841312071
# 21                                          ПАО "ТМК"  7710373095
# 22                     ПАО "Татнефть" им. В.Д. Шашина  1644003838
# 23                     ПАО "Татнефть" им. В.Д. Шашина  1644003838
# 24                                   ПАО "Транснефть"  7706061801
# 25                                      ПАО "ФСК ЕЭС"  4716016979
# 26                                      ПАО "ФосАгро"  7736216869
# 27                                  ПАО "Энел Россия"  6671156423
# 28                                  ПАО АФК "Система"  7703104630
# 29                               ПАО Московская Биржа  7702077840
# 30                                       ПАО Сбербанк  7707083893
# 31                                       ПАО Сбербанк  7707083893
# 32                          Яндекс Н.В. (Yandex N.V.)    10034514
# 33                            Лента Лтд. (Lenta Ltd.)    10034238
# 34                                       ПАО "Юнипро"  8602067092
# 35                                    ПАО "Интер РАО"  2320109650
# 36  Юнайтед Компани РУСАЛ Плс (United Company RUSA...    10035101
# 37                    ПАО "МОСКОВСКИЙ КРЕДИТНЫЙ БАНК"  7734202860
# 38                                          ПАО "ММК"  7414003633
# 39                                        ПАО "Полюс"  7703389295
# 40                                         ПАО "НЛМК"  4823006703
# 41                                      ПАО "Россети"  7728662669
# 42                                  ПАО "Детский мир"  7729355029
# 43                             Икс 5 Ритейл Груп Н.В.    10037240
# 44                  АО "Сбербанк Управление Активами"  7710183778
# 45                           ПАО "Аптечная сеть 36,6"  7722266450
# 46                                        ПАО "ОГК-2"  2607018122
# 47                                   ПАО "Распадская"  4214002316
# 48                               ПАО "Сургутнефтегаз"  8602060555
# 49                               ПАО "Сургутнефтегаз"  8602060555
# 50                      ПАО "МРСК Центра и Приволжья"  5260200603
# 51                                ОАО "Мультисистема"  7719815118
# 52                                ПАО "Газпром нефть"  5504036333
# 53                         ПАО "Центральный телеграф"  7710146208
# 54                           ПАО "Нижнекамскнефтехим"  1651000010
# 55                                    ПАО "Ленэнерго"  7803002209
# 56                                 ПАО АНК "Башнефть"   274051582
# 57                  АО "Сбербанк Управление Активами"  7710183778
#
#                                         Ценная бумага  \
# 0         Акции обыкновенные бездокументарные именные
# 1                                  акции обыкновенные
# 2                                  Акции обыкновенные
# 3                                  Акции обыкновенные
# 4         акция обыкновенная бездокументарная именная
# 5                                  Акции обыкновенные
# 6                                  Акции обыкновенные
# 7                                  Акции обыкновенные
# 8                                  Акции обыкновенные
# 9                                  Акции обыкновенные
# 10                                 Акции обыкновенные
# 11        акции обыкновенные именные бездокументарные
# 12                            акции привилегированные
# 13                                 акции обыкновенные
# 14        обыкновенные именные бездокументарные акции
# 15                                 Акции обыкновенные
# 16                                 акции обыкновенные
# 17        Акции обыкновенные именные бездокументарные
# 18                                 Акции обыкновенные
# 19                                 Акции обыкновенные
# 20                                 Акции обыкновенные
# 21                                 акции обыкновенные
# 22                            Акции привилегированные
# 23                                 Акции обыкновенные
# 24                            акции привилегированные
# 25                                 Акции обыкновенные
# 26                                 акции обыкновенные
# 27        обыкновенные бездокументарные именные акции
# 28        Акции обыкновенные именные бездокументарные
# 29                                 акции обыкновенные
# 30                                 Акции обыкновенные
# 31                            Акции привилегированные
# 32  Обыкновенные именные бездокументарные акции кл...
# 33  Глобальные депозитарные расписки, представляющ...
# 34                                 акции обыкновенные
# 35                                 акции обыкновенные
# 36                                 акции обыкновенные
# 37                                 акции обыкновенные
# 38                                 Акции обыкновенные
# 39                                 акции обыкновенные
# 40                                 Акции обыкновенные
# 41                                 акции обыкновенные
# 42                                 акции обыкновенные
# 43  Глобальные депозитарные расписки, представляющ...
# 44  инвестиционные паи Биржевого паевого инвестици...
# 45                                 акции обыкновенные
# 46                                 Акции обыкновенные
# 47                                 Акции обыкновенные
# 48                                 Акции обыкновенные
# 49                            Акции привилегированные
# 50                                 Акции обыкновенные
# 51                                 акции обыкновенные
# 52                         обыкновенные именные акции
# 53  акции привилегированные именные бездокументарн...
# 54                            Акции привилегированные
# 55                            Акции привилегированные
# 56                            Акции привилегированные
# 57  инвестиционные паи Открытого паевого инвестици...
#
#                                     Тип ценной бумаги Гос. рег. номер  \
# 0                         Акции иностранного эмитента             NaN
# 1                                  Акция обыкновенная    1-03-40046-N
# 2                                  Акция обыкновенная       10401000B
# 3                                  Акция обыкновенная    1-01-00010-A
# 4                                  Акция обыкновенная    1-01-40155-F
# 5                                  Акция обыкновенная    1-02-00028-A
# 6                                  Акция обыкновенная    1-02-01556-A
# 7                                  Акция обыкновенная    1-01-55234-E
# 8                                  Акция обыкновенная    1-01-00077-A
# 9                                  Акция обыкновенная    1-02-11700-A
# 10                                 Акция обыкновенная    1-01-04715-A
# 11                                 Акция обыкновенная    1-01-60525-P
# 12                            Акция привилегированная    2-01-55005-E
# 13                                 Акция обыкновенная    1-01-55005-E
# 14                                 Акция обыкновенная    1-01-00085-A
# 15                                 Акция обыкновенная    1-02-00122-A
# 16                                 Акция обыкновенная    1-02-00268-E
# 17                                 Акция обыкновенная    1-01-00124-A
# 18                                 Акция обыкновенная    1-01-55038-E
# 19                                 Акция обыкновенная    1-02-00143-A
# 20                                 Акция обыкновенная    1-01-03388-D
# 21                                 Акция обыкновенная    1-01-29031-H
# 22                            Акция привилегированная    2-03-00161-A
# 23                                 Акция обыкновенная    1-03-00161-A
# 24                            Акция привилегированная    2-01-00206-A
# 25                                 Акция обыкновенная    1-01-65018-D
# 26                                 Акция обыкновенная    1-02-06556-A
# 27                                 Акция обыкновенная    1-01-50077-A
# 28                                 Акция обыкновенная    1-05-01669-A
# 29                                 Акция обыкновенная    1-05-08443-H
# 30                                 Акция обыкновенная       10301481B
# 31                            Акция привилегированная       20301481B
# 32                        Акции иностранного эмитента             NaN
# 33  Депозитарные расписки иностранного эмитента на...             NaN
# 34                                 Акция обыкновенная    1-02-65104-D
# 35                                 Акция обыкновенная    1-04-33498-E
# 36                        Акции иностранного эмитента             NaN
# 37                                 Акция обыкновенная       10101978B
# 38                                 Акция обыкновенная    1-03-00078-A
# 39                                 Акция обыкновенная    1-01-55192-E
# 40                                 Акция обыкновенная    1-01-00102-A
# 41                                 Акция обыкновенная    1-01-55385-E
# 42                                 Акция обыкновенная    1-02-00844-A
# 43  Депозитарные расписки иностранного эмитента на...             NaN
# 44                                 Пай биржевого ПИФа            3629
# 45                                 Акция обыкновенная    1-01-07335-A
# 46                                 Акция обыкновенная    1-02-65105-D
# 47                                 Акция обыкновенная    1-04-21725-N
# 48                                 Акция обыкновенная    1-01-00155-A
# 49                            Акция привилегированная    2-01-00155-A
# 50                                 Акция обыкновенная    1-01-12665-E
# 51                                 Акция обыкновенная    1-01-15149-A
# 52                                 Акция обыкновенная    1-01-00146-A
# 53                            Акция привилегированная    2-03-00327-A
# 54                            Акция привилегированная    2-02-00096-A
# 55                            Акция привилегированная    2-01-00073-A
# 56                            Акция привилегированная    2-01-00013-A
# 57                                 Пай открытого ПИФа            3428
#
#    Дата регистрации    Номинал                 Объем  Торговый код  \
# 0               NaT        NaN           469 506 028          POLY
# 1        2011-08-25   0.500000         7 364 965 630          ALRS
# 2        2006-09-29   0.010000    12 960 541 337 338          VTBR
# 3        2004-01-23   1.000000         1 110 616 299          AFLT
# 4        2006-12-12   1.000000           158 245 476          GMKN
# 5        1998-12-30   5.000000        23 673 512 900          GAZP
# 6        1998-11-10  62.500000           660 497 344          PIKK
# 7        2006-09-28   0.250000           103 030 215          LSRG
# 8        2003-06-25   0.025000           750 000 000          LKOH
# 9        2007-08-23  10.000000           179 768 227          MVID
# 10       2004-01-22   0.100000         1 998 381 575          MTSS
# 11       2004-03-04   0.010000           101 911 355          MGNT
# 12       2008-06-05  10.000000           138 756 915         MTLRP
# 13       2003-04-29  10.000000           416 270 745          MTLR
# 14       2003-06-17   1.000000        39 749 359 700          MSNG
# 15       2005-09-29   0.010000        10 598 177 817          ROSN
# 16       2006-07-20   0.100000         3 036 306 000          NVTK
# 17       2003-09-09   0.002500         2 574 914 954          RTKM
# 18       2005-02-22   1.000000       426 288 813 551          HYDR
# 19       2004-11-30   0.010000           837 718 660          CHMF
# 20       2005-05-17   0.010000  3 854 341 416 571,43          TGKA
# 21       2001-07-26  10.000000         1 033 135 366          TRMK
# 22       2001-10-26   1.000000           147 508 500         TATNP
# 23       2001-10-26   1.000000         2 178 690 700          TATN
# 24       2007-12-20   1.000000             1 554 875         TRNFP
# 25       2002-09-10   0.500000     1 274 665 323 063          FEES
# 26       2012-02-14   2.500000           129 500 000          PHOR
# 27       2004-12-24   1.000000        35 371 898 370          ENRU
# 28       2007-11-01   0.090000         9 650 000 000          AFKS
# 29       2011-09-16   1.000000         2 276 401 458          MOEX
# 30       2007-07-11   3.000000        21 586 948 000          SBER
# 31       2007-07-11   3.000000         1 000 000 000         SBERP
# 32              NaT   0.010000           292 567 655          YNDX
# 33              NaT        NaN           487 084 815          LNTA
# 34       2007-04-19   0.400000        63 048 706 145          UPRO
# 35       2014-12-23   2.809767       104 400 000 000          IRAO
# 36              NaT   0.010000        15 193 014 862          RUAL
# 37       1999-08-18   1.000000        27 079 709 866          CBOM
# 38       2002-11-05   1.000000        11 174 330 000          MAGN
# 39       2006-04-27   1.000000           133 561 119          PLZL
# 40       2004-04-09   1.000000         5 993 227 240          NLMK
# 41       2008-07-29   1.000000       198 827 865 141          RSTI
# 42       2014-02-11   0.000400           739 000 000          DSKY
# 43              NaT        NaN           271 572 872          FIVE
# 44       2018-12-24        NaN                   NaN          SBGB
# 45       2002-08-14   0.640000         8 330 647 246          APTK
# 46       2007-04-19   0.362700       110 441 160 870          OGKB
# 47       2006-04-18   0.004000           703 191 442          RASP
# 48       2003-06-24   1.000000        35 725 994 705          SNGS
# 49       2003-06-24   1.000000         7 701 998 235         SNGSP
# 50       2007-08-20   0.100000       112 697 817 043          MRKP
# 51       2012-10-30   0.001000           100 000 000          MSST
# 52       1995-10-17   0.001600         4 741 299 639          SIBN
# 53       2002-12-20   1.000000            55 389 000         CNTLP
# 54       2003-08-15   1.000000           218 983 750         NKNCP
# 55       2003-06-27   1.000000            93 264 311         LSNGP
# 56       2004-04-07   1.000000            29 788 012         BANEP
# 57       2017-11-23        NaN                   NaN  RU000A1002D0
#
#    Дата погашения Дата обращения Предназначение для квалинвесторов
# 0             NaT            NaT                               NaN
# 1             NaT            NaT                               NaN
# 2             NaT            NaT                               NaN
# 3             NaT            NaT                               NaN
# 4             NaT            NaT                               NaN
# 5             NaT            NaT                               NaN
# 6             NaT            NaT                               NaN
# 7             NaT            NaT                               NaN
# 8             NaT            NaT                               NaN
# 9             NaT            NaT                               NaN
# 10            NaT            NaT                               NaN
# 11            NaT            NaT                               NaN
# 12            NaT            NaT                               NaN
# 13            NaT            NaT                               NaN
# 14            NaT            NaT                               NaN
# 15            NaT            NaT                               NaN
# 16            NaT            NaT                               NaN
# 17            NaT            NaT                               NaN
# 18            NaT            NaT                               NaN
# 19            NaT            NaT                               NaN
# 20            NaT            NaT                               NaN
# 21            NaT            NaT                               NaN
# 22            NaT            NaT                               NaN
# 23            NaT            NaT                               NaN
# 24            NaT            NaT                               NaN
# 25     2002-09-10            NaT                               NaN
# 26            NaT            NaT                               NaN
# 27            NaT            NaT                               NaN
# 28            NaT            NaT                               NaN
# 29            NaT            NaT                               NaN
# 30            NaT            NaT                               NaN
# 31            NaT            NaT                               NaN
# 32            NaT            NaT                               NaN
# 33            NaT            NaT                               NaN
# 34            NaT            NaT                               NaN
# 35            NaT     2015-01-20                               NaN
# 36            NaT     2015-03-30                               NaN
# 37            NaT     2015-06-22                               NaN
# 38            NaT            NaT                               NaN
# 39            NaT            NaT                               NaN
# 40            NaT            NaT                               NaN
# 41            NaT            NaT                               NaN
# 42            NaT     2017-02-10                               NaN
# 43            NaT     2018-02-01                               NaN
# 44     2033-07-05     2019-01-25                               NaN
# 45            NaT            NaT                               NaN
# 46            NaT            NaT                               NaN
# 47            NaT            NaT                               NaN
# 48            NaT            NaT                               NaN
# 49            NaT            NaT                               NaN
# 50            NaT            NaT                               NaN
# 51            NaT            NaT                               NaN
# 52            NaT            NaT                               NaN
# 53            NaT            NaT                               NaN
# 54            NaT            NaT                               NaN
# 55            NaT            NaT                               NaN
# 56            NaT            NaT                               NaN
# 57     2027-08-17     2019-04-17                               NaN

# %% [markdown]
# Поскольку паевые фонды и страховые компании (крупные игроки рынка) имеют право работать только с тикерами первого уровня листинга, то из всего списка (58 тикеров) оставляем 45 верхних, принадлежащих первому уровню листинга.

# %%
spec = spec.loc[spec['Листинг']=='Первый уровень']

# %% [markdown]
# Почти итоговый список выбранных инструментов

# %%
spec[['Эмитент', 'Тип ценной бумаги', 'Торговый код']].sort_values(
    by='Торговый код').reset_index(drop=True)
# Out:
#                                               Эмитент  \
# 0                                   ПАО АФК "Система"
# 1                                      ПАО "Аэрофлот"
# 2                                   АК "АЛРОСА" (ПАО)
# 3                     ПАО "МОСКОВСКИЙ КРЕДИТНЫЙ БАНК"
# 4                                    ПАО "Северсталь"
# 5                                   ПАО "Детский мир"
# 6                                   ПАО "Энел Россия"
# 7                                       ПАО "ФСК ЕЭС"
# 8                              Икс 5 Ритейл Груп Н.В.
# 9                                       ПАО "Газпром"
# 10                       ПАО "ГМК "Норильский никель"
# 11                                     ПАО "РусГидро"
# 12                                    ПАО "Интер РАО"
# 13                                       ПАО "ЛУКОЙЛ"
# 14                            Лента Лтд. (Lenta Ltd.)
# 15                                   ПАО "Группа ЛСР"
# 16                                          ПАО "ММК"
# 17                                       ПАО "Магнит"
# 18                               ПАО Московская Биржа
# 19                                    ПАО "Мосэнерго"
# 20                                        ПАО "Мечел"
# 21                                        ПАО "Мечел"
# 22                                          ПАО "МТС"
# 23                                      ПАО "М.видео"
# 24                                         ПАО "НЛМК"
# 25                                      ПАО "НОВАТЭК"
# 26                                      ПАО "ФосАгро"
# 27                          ПАО "Группа Компаний ПИК"
# 28                                        ПАО "Полюс"
# 29  Polymetal International plc (Полиметалл Интерн...
# 30                                 ПАО "НК "Роснефть"
# 31                                      ПАО "Россети"
# 32                                   ПАО "Ростелеком"
# 33  Юнайтед Компани РУСАЛ Плс (United Company RUSA...
# 34                                       ПАО Сбербанк
# 35                                       ПАО Сбербанк
# 36                  АО "Сбербанк Управление Активами"
# 37                     ПАО "Татнефть" им. В.Д. Шашина
# 38                     ПАО "Татнефть" им. В.Д. Шашина
# 39                                        ПАО "ТГК-1"
# 40                                          ПАО "ТМК"
# 41                                   ПАО "Транснефть"
# 42                                       ПАО "Юнипро"
# 43                                     Банк ВТБ (ПАО)
# 44                          Яндекс Н.В. (Yandex N.V.)
#
#                                     Тип ценной бумаги Торговый код
# 0                                  Акция обыкновенная         AFKS
# 1                                  Акция обыкновенная         AFLT
# 2                                  Акция обыкновенная         ALRS
# 3                                  Акция обыкновенная         CBOM
# 4                                  Акция обыкновенная         CHMF
# 5                                  Акция обыкновенная         DSKY
# 6                                  Акция обыкновенная         ENRU
# 7                                  Акция обыкновенная         FEES
# 8   Депозитарные расписки иностранного эмитента на...         FIVE
# 9                                  Акция обыкновенная         GAZP
# 10                                 Акция обыкновенная         GMKN
# 11                                 Акция обыкновенная         HYDR
# 12                                 Акция обыкновенная         IRAO
# 13                                 Акция обыкновенная         LKOH
# 14  Депозитарные расписки иностранного эмитента на...         LNTA
# 15                                 Акция обыкновенная         LSRG
# 16                                 Акция обыкновенная         MAGN
# 17                                 Акция обыкновенная         MGNT
# 18                                 Акция обыкновенная         MOEX
# 19                                 Акция обыкновенная         MSNG
# 20                                 Акция обыкновенная         MTLR
# 21                            Акция привилегированная        MTLRP
# 22                                 Акция обыкновенная         MTSS
# 23                                 Акция обыкновенная         MVID
# 24                                 Акция обыкновенная         NLMK
# 25                                 Акция обыкновенная         NVTK
# 26                                 Акция обыкновенная         PHOR
# 27                                 Акция обыкновенная         PIKK
# 28                                 Акция обыкновенная         PLZL
# 29                        Акции иностранного эмитента         POLY
# 30                                 Акция обыкновенная         ROSN
# 31                                 Акция обыкновенная         RSTI
# 32                                 Акция обыкновенная         RTKM
# 33                        Акции иностранного эмитента         RUAL
# 34                                 Акция обыкновенная         SBER
# 35                            Акция привилегированная        SBERP
# 36                                 Пай биржевого ПИФа         SBGB
# 37                                 Акция обыкновенная         TATN
# 38                            Акция привилегированная        TATNP
# 39                                 Акция обыкновенная         TGKA
# 40                                 Акция обыкновенная         TRMK
# 41                            Акция привилегированная        TRNFP
# 42                                 Акция обыкновенная         UPRO
# 43                                 Акция обыкновенная         VTBR
# 44                        Акции иностранного эмитента         YNDX

# %% [markdown]
# Есть выпадающий актив: пай Сбербанка "Управление Активами". Его стоит исключить, поскольку фактически это портфель из активов. Итоговый список: 44 финансового инструмента.

# %%
spec = spec.loc[spec['Торговый код']!='SBGB'].reset_index(drop=True)

spec.to_excel('./data_results/selection/volume_instruments_specification.xlsx', index=False)
